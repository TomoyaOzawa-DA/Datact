# %% [markdown]
# # テキストマイニング: ユーザーレビューの分析

# %% [markdown]
# ## 1. はじめに
# ### 1.1. 本日のゴール
#
# **「テキストって数字みたいに分析できるのか。」**と一瞬でも感じること。
#
# ### 1.2. テキストマイニングとは？
#
# - テキスト（文字）を定量的に分析する手法。具体的には、
#  - [形態素解析](https://ledge.ai/morpho_analysis_japan/): 文章を単語レベルに分割する
#  - [wordcloud](https://qiita.com/kenmatsu4/items/9b6ac74f831443d29074): 単語の出現頻度を可視化する
#  - 共起ネットワーク: 単語間の繋がりを可視化する
#    - [KH Coder](https://toukeier.hatenablog.com/entry/2019/08/19/203408)というフリーソフトで作成することも出来るみたい。
#  - [word2vec](https://qiita.com/g-k/items/69afa87c73654af49d36)(自然言語処理): 単語をベクトルとして扱えるようにする手法。これを使うと、深層学習モデルにテキストデータを入力出来るようになる。
# - マーケティングの文脈だと、ユーザーのレビューデータやSNSの投稿、アンケートの自由記述欄が主な分析対象
#  - レビューデータやSNSの投稿はWebスクレイピングやAPIを叩けば簡単に取得できる
#
# ### 1.3. ハンズオンのお題
#
# - みなさんはECサイトでスキーウェアを販売するB社の売り上げ向上プロジェクトにアサインされました。
# - 先方は特に子供向けのスキーウェアの売り上げがイマイチ伸びないことを問題視しています。
# - みなさんの中で議論をした結果、商品をうまく訴求出来ていないこと（ユーザーが感じているベネフィットと訴求内容のズレ）が1つの仮説として浮かんできました。
# - そこで、B社子供向けのスキーウェアを購入したユーザーのレビューを収集し、テキストマイニングでユーザーの声を定量的に評価することにしました。
#
# ### 1.4. ハンズオンの構成
#
# 2. **[データの前処理](#first-bullet)**
# 3. **[形態素解析](#second-bullet)**
# 4. **[テキストの出現頻度の可視化; Wordcloud](#third-bullet)**
# 5. **[テキストの繋がり; 共起ネットワーク](#fourth-bullet)**
# 6. **[おわりに](#final-bullet)**

# %% [markdown]
# ## 2. データの前処理<a class="anchor" id="first-bullet"></a>
# ### 2.1. 読み込み
# いつも通り`pandas`を使っていきます。今回はB社子供用スキーウェアに関する楽天のレビューデータを使います。
#
# - rakuten_review_high.csv
#     - 評価が5段階中の4以上をつけているユーザーのレビュー。（ほとんどの商品の平均評価が4点台でした。）
# - rakuten_review_low.csv
#     - 評価が5段階中の4未満をつけているユーザーのレビュー
#     - ほとんどの商品の平均評価が4点台だったので、サンプル数は少ないです。

# %%
import pandas as pd

# %%
df_low = pd.read_csv("rakuten_review_low.csv", header = None)
df_low.head()
# Out:
#                                                    0
# 0  120センチ前半の子にサイズ130を購入しました。\nあまりにもダボダボしてるのは嫌なので説...
# 1  １３５センチ、３３キロの娘に。\n大きくて、調整ヒモ最後まで絞っても、引きずってしまいました...
# 2                         デザイン・防水・着こゴチお勧めです。サイズは大きめ！
# 3  スノボ用だからなのかダボダボで、子供が来にくいといって嫌々きました。自分できれない子供には来...
# 4  娘に購入しました。とっても気に入りました。サイズですが、上は丁度よかったのですが、下は幅広く...

# %%
df_high = pd.read_csv("rakuten_review_high.csv", header = None)
df_high.head()
# Out:
#                                                    0
# 0  身長107センチ、体重18キロ、5歳の男児用に120センチを購入したところ、ママ！大人のが届...
# 1  安く買えて良かったです。\n身長140センチで150サイズ買いましたが、裾の調整で問題なさそ...
# 2  143センチの息子に150を購入。少し大き目でしたがベルト部分や袖の長さを調節できたので問題...
# 3  色、柄とも豊富で、どれもステキです。\n145cmですが150cmのサイズで\n大きいかな…...
# 4  注文してからすぐに届きました！\n商品もかっこ良くて気に入りました！\nまだ実際に使用してい...

# %% [markdown]
# 改行が`\n`という文字列として認識されてしまいました。消しましょう。コードを書く時には、消すというより無に置換するといった書き方をします。
#
# - この置換をやってくれるのが`str.replace()`という関数です。（今回はDataFrameのある1列に対して実行するので、`str.replace()`を使います。ベクトルに対して置換をする時は`replace`で出来ます。）
# - 参考サイト
#     - [pandasの文字列メソッドで置換や空白削除などの処理を行う](https://note.nkmk.me/python-pandas-str-replace-strip-etc/)
#     - [Pythonで文字列を置換（replace, translate, re.sub, re.subn）](https://note.nkmk.me/python-str-replace-translate-re-sub/)

# %%
df_high[0] = df_high[0].str.replace('\n', '')
df_high.head()
# Out:
#                                                    0
# 0  身長107センチ、体重18キロ、5歳の男児用に120センチを購入したところ、ママ！大人のが届...
# 1   安く買えて良かったです。身長140センチで150サイズ買いましたが、裾の調整で問題なさそうです。
# 2  143センチの息子に150を購入。少し大き目でしたがベルト部分や袖の長さを調節できたので問題...
# 3  色、柄とも豊富で、どれもステキです。145cmですが150cmのサイズで大きいかな…って感じ...
# 4  注文してからすぐに届きました！商品もかっこ良くて気に入りました！まだ実際に使用していないので...

# %% [markdown]
# ## 3. 形態素解析<a class="anchor" id="second-bullet"></a>

# %% [markdown]
# - 文章を単語レベルに区切る操作が形態素解析です。
# - 形態素解析のライブラリとして、Mecabやjanomeがあります。
#  - Mecabの方が新しい単語にも対応している。（「インスタ映え」とか。）その一方で、設定が少しめんどくさい。
#  - 今回はjanomeを使ってみます。
# - 参考資料
#  - [janomeの基本的な使い方](https://note.nkmk.me/python-janome-tutorial/)

# %% [markdown]
# ### 3.1. janomeの基本的な使い方
# anaconda環境の人もローカルPCに環境構築している人もターミナルで`pip install janome`を実行して、`janome`パッケージをインストールしましょう。

# %%
from janome.tokenizer import Tokenizer

# %% [markdown]
# #### 3.1.1. 単語に分割
# 例として、『本日はデータサイエンス×マーケティング勉強会に参加していただき、ありがとうございます。』を単語レベルに分割してみます。（インスタンスと呼ばれる）`Tokenizer()`の中にある`tokenize()`という関数を使うと、単語レベルに分割してくれます。

# %%
t = Tokenizer()
text = '本日はデータサイエンス×マーケティング勉強会に参加していただき、ありがとうございます。'
result = t.tokenize(text)

# %%
result
# Out:
# <generator object Tokenizer.__tokenize_stream at 0x122382d60>

# %% [markdown]
# 結果を見る時には`print()`を使います。

# %%
for token in result:
    print(token)
# Out:
# 本日	名詞,副詞可能,*,*,*,*,本日,ホンジツ,ホンジツ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# データ	名詞,一般,*,*,*,*,データ,データ,データ
# サイエンス	名詞,一般,*,*,*,*,サイエンス,サイエンス,サイエンス
# ×	記号,一般,*,*,*,*,×,カケル,カケル
# マーケティング	名詞,一般,*,*,*,*,マーケティング,マーケティング,マーケティング
# 勉強	名詞,サ変接続,*,*,*,*,勉強,ベンキョウ,ベンキョー
# 会	名詞,接尾,一般,*,*,*,会,カイ,カイ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 参加	名詞,サ変接続,*,*,*,*,参加,サンカ,サンカ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いただき	動詞,非自立,*,*,五段・カ行イ音便,連用形,いただく,イタダキ,イタダキ
# 、	記号,読点,*,*,*,*,、,、,、
# ありがとう	感動詞,*,*,*,*,*,ありがとう,アリガトウ,アリガトー
# ござい	助動詞,*,*,*,五段・ラ行特殊,連用形,ござる,ゴザイ,ゴザイ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。

# %%
t = Tokenizer()
text = '本日はデータサイエンス×マーケティング勉強会に参加していただき、ありがとうございます。'
result = t.tokenize(text)

list(result)
# Out:
# [<janome.tokenizer.Token at 0x144a0e670>,
#  <janome.tokenizer.Token at 0x144a0ed30>,
#  <janome.tokenizer.Token at 0x144a0e0a0>,
#  <janome.tokenizer.Token at 0x144a0e700>,
#  <janome.tokenizer.Token at 0x144a0eb20>,
#  <janome.tokenizer.Token at 0x144a0e850>,
#  <janome.tokenizer.Token at 0x144a0efd0>,
#  <janome.tokenizer.Token at 0x144a0e730>,
#  <janome.tokenizer.Token at 0x144a0ea60>,
#  <janome.tokenizer.Token at 0x144a0e040>,
#  <janome.tokenizer.Token at 0x144a0e310>,
#  <janome.tokenizer.Token at 0x144a0e940>,
#  <janome.tokenizer.Token at 0x144a0ef70>,
#  <janome.tokenizer.Token at 0x144a0ef40>,
#  <janome.tokenizer.Token at 0x144a0edf0>,
#  <janome.tokenizer.Token at 0x144a0ee50>,
#  <janome.tokenizer.Token at 0x144a0e070>,
#  <janome.tokenizer.Token at 0x144a0e8b0>]

# %% [markdown]
# これら`<janome.tokenizer.Token at ...>`に分割した単語の情報が格納されています。それぞれに関してみていくために、for構文で`print()`させました。

# %% [markdown]
# #### 3.1.2. 表層型と基本形
#
# - 表層形: データの中で使われているそのままの形
#     - 単語レベルに分割した後に、`.surface`を使うことで、取り出せます
# - 基本形: 活用してない形。動詞でいうところの終止形？
#     - `.base_form`で取り出せます。

# %%
t = Tokenizer()
text = '本日はデータサイエンス×マーケティング勉強会に参加していただき、ありがとうございます。'
result = t.tokenize(text)

print("表層形"+ "|" +"基本形")
print("==================================")

for token in result:
    print(token.surface + "|" + token.base_form)
# Out:
# 表層形|基本形
# ==================================
# 本日|本日
# は|は
# データ|データ
# サイエンス|サイエンス
# ×|×
# マーケティング|マーケティング
# 勉強|勉強
# 会|会
# に|に
# 参加|参加
# し|する
# て|て
# いただき|いただく
# 、|、
# ありがとう|ありがとう
# ござい|ござる
# ます|ます
# 。|。

# %% [markdown]
# #### 3.1.3. 品詞
#
# - `part_of_speech`で単語の品詞を取り出すことが出来ます。
#     - 品詞,品詞細分類1,品詞細分類2,品詞細分類3の順で出力されます。
# - `.split()`関数を使うことで()内で指定した文字で分割することが出来ます。
#     - 詳しくは[こちら](https://note.nkmk.me/python-split-rsplit-splitlines-re/)を参考にどうぞ

# %%
t = Tokenizer()
text = '本日'
result = t.tokenize(text)

for token in result:
    pos = token.part_of_speech
    #pos = token.part_of_speech.split(',')

# %%
pos
# Out:
# '名詞,副詞可能,*,*'

# %%
pos[0]
# Out:
# '名'

# %% [markdown]
# #### 3.1.4. 特定の品詞の文字列を抽出する

# %%
t = Tokenizer()
text = '本日はデータサイエンス×マーケティング勉強会に参加していただき、ありがとうございます。'
result = t.tokenize(text)

# 特定の品詞を保存しておく箱（リスト）
words = []

for token in result:
    #品詞を抽出
    pos = token.part_of_speech.split(',')[0]
    
    # もし品詞が名詞だったら、追加する
    if pos == '名詞':
        words.append(token.base_form)

# %%
words
# Out:
# ['本日', 'データ', 'サイエンス', 'マーケティング', '勉強', '会', '参加']

# %% [markdown]
# - `append()`関数を使うことで、箱（リスト）に要素を加えることが出来ます
# - リストに関する操作は[このサイト](https://note.nkmk.me/python-list-append-extend-insert/)にまとまっています。

# %%
# 例えば、、
name = ["Tomoya", "Kazuma"]
name.append("Kazuki")
name
# Out:
# ['Tomoya', 'Kazuma', 'Kazuki']

# %% [markdown]
# ### 3.2. レビューデータを形態素解析にかけてみる
# #### 3.2.1. データを変形
# 注意すべき点としては、データフレームから1つの文字列（今までの話だと、'本日はデータサイエンス×マーケティング勉強会に参加していただき、ありがとうございます。'）へと変形しなくてはいけないことです。2段階のステップを踏みます。
#
# 1. Series（データフレームの1列）をリストにする
#     - `.values.tolist()`関数
# 2. リストを1つの文字列にする
#     - `join()`関数。()内で間に挿入する文字列を指定することが出来る。

# %%
list_high = df_high[0].values.tolist()

# %%
list_test = ','.join(list_high)

# %% [markdown]
# #### 3.2.2. 単語レベルに分割

# %%
t = Tokenizer()
text = list_test
result = t.tokenize(text)

count = 0

# 最初の10単語だけ出力
for token in result:
    print(token)
    
    count += 1
    
    if count == 10:
        break
# Out:
# 身長	名詞,一般,*,*,*,*,身長,シンチョウ,シンチョー
# 107	名詞,数,*,*,*,*,107,*,*
# センチ	名詞,接尾,助数詞,*,*,*,センチ,センチ,センチ
# 、	記号,読点,*,*,*,*,、,、,、
# 体重	名詞,一般,*,*,*,*,体重,タイジュウ,タイジュー
# 18	名詞,数,*,*,*,*,18,*,*
# キロ	名詞,接尾,助数詞,*,*,*,キロ,キロ,キロ
# 、	記号,読点,*,*,*,*,、,、,、
# 5	名詞,数,*,*,*,*,5,*,*
# 歳	名詞,接尾,助数詞,*,*,*,歳,サイ,サイ

# %% [markdown]
# #### 3.2.3. 特定の品詞だけを抽出

# %%
t = Tokenizer()
text = list_test
result = t.tokenize(text)

words = []

for token in result:
    #品詞から名詞だけ抽出
    pos = token.part_of_speech.split(',')[0]
    
    if pos == '名詞':
        words.append(token.base_form)

# %%
#初めから10個をみてみます。
words[0:10]
# Out:
# ['身長', '107', 'センチ', '体重', '18', 'キロ', '5', '歳', '男児', '用']

# %% [markdown]
# ## 4. テキストの出現頻度の可視化; Wordcloud<a class="anchor" id="third-bullet"></a>
# ### 4.1. word cloud の基本
# Anaconda環境の人はAnaconda promptで`conda install -c conda-forge wordcloud`を実行してください。

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# リストを文字列に変換
word_chain = ','.join(words)

# %%
# ワードクラウド作成
W_123 = WordCloud(width = 900, height = 500, background_color='white', colormap='summer', collocations=False,font_path='/System/Library/Fonts/ヒラギノ丸ゴ ProN W4.ttc').generate(word_chain)

plt.figure(figsize=(15,12))
plt.imshow(W_123)
plt.axis('off')
plt.show()

# %% [markdown]
# - background_colorで背景色、colormapで文字の色を指定出来ます
#     - colormapに関しては[こちら](https://karupoimou.hatenablog.com/entry/2019/05/17/153207)から色々選べます
# - collocationで複合語の処理が可能です。これを指定しないと、同じ単語が2回出てくることがあります
#     - 詳しくは[こちら](https://qiita.com/kbs/items/33b3dd6dae15f7b20b9e)
# - よくみると、入っていて当たり前な単語がありますね。これらを除くことも簡単に出来ます。
#     - stopwordsとして指定します。

# %%
stop_word = [u'の', u'購入', u'そう']

# ワードクラウド作成
W_123 = WordCloud(width = 900, height = 500, 
                  background_color='white', colormap='summer', 
                  collocations=False,
                  font_path='/System/Library/Fonts/ヒラギノ丸ゴ ProN W4.ttc', 
                  stopwords=set(stop_word)).generate(word_chain)

plt.figure(figsize=(15,12))
plt.imshow(W_123)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 4.2. より簡単に分析出来るようにする
# #### 4.2.1. 関数化

# %% [markdown]
# ここまでの処理を関数にします。data, part_of_speech, stop_wordsの3つを入力すると、自動的にwordcloudが出力されるようにしています。
#
# - data: inputになるデータ,文字列の形でないとエラーでます。
# - part_of_speech: 抽出したい品詞を指定します。
# - stop_words: word_cloudで省きたい言葉を指定します。

# %%
def make_word_cloud(data, part_of_speech, stop_words):
    
    # split 
    t = Tokenizer()
    text = data
    result = t.tokenize(text)
    words = []
    
    if part_of_speech == "all":
        for token in result:
            words.append(token.base_form)
    
    else:
        for token in result:
            pos = token.part_of_speech.split(',')[0]
            
            if pos in part_of_speech:
                words.append(token.base_form)
    
    # make word cloud
    word_chain = ' '.join(words)
    
    W_123 = WordCloud(width = 900, height = 500, background_color='white', colormap='summer', 
                      collocations=False,font_path='/System/Library/Fonts/ヒラギノ丸ゴ ProN W4.ttc', 
                      stopwords=set(stop_words)).generate(word_chain)
    
    plt.figure(figsize=(15,12))
    plt.imshow(W_123)
    plt.axis('off')
    plt.show()

# %% [markdown]
# 関数の挙動をチェック

# %% [markdown]
# 他のテキストにもやってみる

# %%
# DatactのHPのテキスト
data = "Growth with Data Marketing Support your future driven by data. About Us Datactは学生主体のマーケティングコンサルティング団体です 統計ツールを使用したビッグデータ解析を基に、マーケティング調査・戦略立案を行っています MISSION この会社は何を成すために 存在しているのか 「日本を変革する人材を輩出する」 デジタルビジネス時代の到来により、データ活用の重要性が叫ばれる昨今。誰もがその必要性を感じる一方で、社内における人材不足や知見不足からその課題感に着手できていない企業様もまだまだ多いと感じております。 Datactはデータ分析やデータマーケティングに強みを持つ若手社会人/学生が主体となり、クライアント様の抱える事業課題をデータ利活用を通じて解決し事業を伸ばすお手伝いをさせて頂くとともに、こうした共同プロジェクトを国内で数多く実施することでデータ人材を増やし、日本を変革する次世代人材の輩出を目指しています。 VALUE ミッションを実現するための 価値観及び行動指針 01 Think Big 狭い視野で考えてしまうと大きな結果を得ることはできません。リーダーは大胆な方針と方向性をつくり、示すことによって成果を導きます。 02 Take Ownership リーダーは自分のチームだけでなく、会社全体のために行動します。リーダーは「それは私の仕事ではありません」とは決して口にしません。 03 Role Model リーダーは常にロールモデルとして自ら学び機会を追求し続けるだけでなく、次世代を育成し、コーチングにも真剣に取り組みます。 04 Data-driven and Hands-on リーダーは常にデータに基いて判断します・ただしデータを盲信するのではなく現場をつぶさに観察し、現実と照らし合わせながら論理的に最も妥当だと思われる結論を導き出します。 05 Customer Obsession リーダーは常にパートナーを起点に考え行動します。パートナーから信頼を獲得し、維持していくために全力を尽くします。 Our Service Datactは統計解析やデータ分析に基づくマーケティング戦略立案、デジタルマーケティング運用を行い、 パートナー様のデジタル改革を支援します 1. Data Marketing Consulting クライアント様の顧客データ、POSデータ、売上データなどのマーケティングデータを統計学的に解析し、データに基づいた最適のマーケティング戦略を提供します。 Datact はクライアント様の意向に添えるように、ビジネス・マーケティング方針について何度もご相談させていただき、目標に向かってパートナーとして共に歩んでいきます。 【過去のプロジェクト事例】Grip International様とのゴルフウェアECでの売上向上プロジェクト、Brangista様との一般消費財 ECプラットフォーム上でのマーケティングプロジェクト。 2. Workshop and Recruiting データ分析、マーケティングといった高度なスキルを持った学生との接点を持ち、クライアント様の長期インターンや新卒採用へつなげるためのワークショップ企画を行います。学生目線で、スキルのある学生にとってモチベーションとなるケース設定を行い、企業様の生データを盛り込んだ血の通ったインターン・ワークショップを企画運用いたします。 【過去のプロジェクト事例】Cross Marketing様 Winter Internship, SMS様 Winter Internship(仮名称), Data Visualization Workshop 飲食事業、アパレルブランド事業、EC事業などをはじめとする様々な事業にて包括的なデータ分析、マーケティングプランニング、ブランディングデザインを協働させて頂いております"
part_of_speech_test = ["名詞", "形容詞"]
stop_words_test = []

make_word_cloud(data, part_of_speech_test, stop_words_test)

# %%
list_series = df_high[0].values.tolist()
data = ','.join(list_series)
part_of_speech_test = ["名詞", "形容詞"]
stop_words_test = [ u'の',u'購入', u'そう']

make_word_cloud(data, part_of_speech_test, stop_words_test)

# %% [markdown]
# #### 4.2.2. データを絞る
# 「サイズ」がよく出てくるみたいです。どういう文脈で「サイズ」が使われているのでしょうか？「サイズ」を含むレビューに関してもう一度wordcloudを作ってみます。
#
# 1. 「サイズ」を含むかどうかを判別する列を作る
# 2. 作成した列をもとにデータを絞る
#     - `query()`関数が便利です。詳しくは[こちら](https://note.nkmk.me/python-pandas-query/)。

# %%
df_high["flag"] = 0

for i in range(len(df_high.index)):
    
    # サイズが含まれていたらflag = 1になるようにする
    if "サイズ" in df_high.iloc[i, 0]:
        df_high.iloc[i, 1] = 1

# %%
df_high_size = df_high.query('flag == 1')

# %%
df_high_size.head()
# Out:
#                                                     0  flag
# 0   身長107センチ、体重18キロ、5歳の男児用に120センチを購入したところ、ママ！大人のが届...     1
# 1    安く買えて良かったです。身長140センチで150サイズ買いましたが、裾の調整で問題なさそうです。     1
# 3   色、柄とも豊富で、どれもステキです。145cmですが150cmのサイズで大きいかな…って感じ...     1
# 6   レビューを見て、大きめなのは想定していましたが、他社製品と比べると、明らかに2サイズくらい大...     1
# 10  145ｃｍの子供に150サイズで購入。調整できるヒモもついていたし長く着れそうです。カッコイ...     1

# %% [markdown]
# ### Groupwork: word cloud を作ってみましょう
#
# - データを絞ったり、stop_wordsを指定して、色々なword cloudを作成してみてください。
# - ユーザーの声を可視化していく中で、ユーザーはB社子供用スキーウェアに対してどのような評価をしているのか読み取れますか？？

# %% [markdown]
# ## 5. テキストの繋がり; 共起ネットワーク<a class="anchor" id="fourth-bullet"></a>
# ### 5.1. 実装
#
# Anaconda環境の人は`conda install -c lightsource2-tag collection`, `conda install -c anaconda networkx`あたりを実行してください。`japanize_matplotlib`に関しては[このサイト](https://ai-inter1.com/matplotlib-japanize/)の**japanize_matplotlibの利用による日本語対応**を参考にして設定してみてください．

# %%
import itertools
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
# %matplotlib inline 
import japanize_matplotlib

# %% [markdown]
# [参考](https://qiita.com/y_itoh/items/7aa33ba0b1e30b3ea33d)

# %%
# 数字を抜く, regex=Trueで正規表現を使える
df_high[0] = df_high[0].str.replace(r'\d', '', regex=True)
df_high.head()
# Out:
#                                                    0  flag
# 0  身長センチ、体重キロ、歳の男児用にセンチを購入したところ、ママ！大人のが届いたよ！というくら...     1
# 1         安く買えて良かったです。身長センチでサイズ買いましたが、裾の調整で問題なさそうです。     1
# 2  センチの息子にを購入。少し大き目でしたがベルト部分や袖の長さを調節できたので問題なく使用でき...     0
# 3  色、柄とも豊富で、どれもステキです。cmですがcmのサイズで大きいかな…って感じですが、簡単...     1
# 4  注文してからすぐに届きました！商品もかっこ良くて気に入りました！まだ実際に使用していないので...     0

# %%
len(df_high.index)
# Out:
# 1994

# %% [markdown]
# データをランダムにサンプリングして、減らす。※このまま実行すると結構時間がかかるため

# %%
# 再現性の確保
import random
random.seed(0)
# nで数字、fracで割合で指定可能
#df_high = df_high.sample(n = 500)
df_high = df_high.sample(frac = 0.2)

# %%
list_high = df_high[0].values.tolist()

# %%
make_network(list_high, "名詞")

# %%
output = []

for sentence in list_high:
    t = Tokenizer()
    text = sentence
    result = t.tokenize(text)
    
    words = []
    
    for token in result:
        pos = token.part_of_speech.split(',')[0]
        if pos == '名詞':
            words.append(token.base_form)
    
    output.append(words)

# %%
# 文単位の名詞ペアリストを生成
pair_list = [
             list(itertools.combinations(n, 2))
             for n in output if len(output) >=2
             ]

# 名詞ペアリストの平坦化
all_pairs = []
for u in pair_list:
    all_pairs.extend(u)

# 名詞ペアの頻度をカウント
cnt_pairs = Counter(all_pairs)

# %%
cnt_pairs
# Out:
# Counter({('身長', 'cm'): 20,
#          ('身長', '息子'): 20,
#          ('身長', 'サイズ'): 28,
#          ('身長', '上'): 2,
#          ('身長', '紐'): 7,
#          ('身長', '調節'): 17,
#          ('身長', '大丈夫'): 6,
#          ('身長', '下'): 6,
#          ('身長', '細身'): 7,
#          ('身長', 'デザイン'): 15,
#          ('身長', '着心地'): 3,
#          ('身長', 'みたい'): 4,
#          ('身長', 'スキー'): 7,
#          ('身長', '楽しみ'): 4,
#          ('cm', '息子'): 22,
#          ('cm', 'サイズ'): 43,
#          ('cm', 'cm'): 15,
#          ('cm', '上'): 6,
#          ('cm', '紐'): 12,
#          ('cm', '調節'): 20,
#          ('cm', '大丈夫'): 6,
#          ('cm', '下'): 4,
#          ('cm', '細身'): 8,
#          ('cm', 'デザイン'): 13,
#          ('cm', '着心地'): 4,
#          ('cm', 'みたい'): 7,
#          ('cm', 'スキー'): 7,
#          ('cm', '楽しみ'): 7,
#          ('息子', 'サイズ'): 26,
#          ('息子', 'cm'): 11,
#          ('息子', '上'): 6,
#          ('息子', '紐'): 6,
#          ('息子', '調節'): 23,
#          ('息子', '大丈夫'): 8,
#          ('息子', '下'): 7,
#          ('息子', '細身'): 3,
#          ('息子', '息子'): 18,
#          ('息子', 'デザイン'): 22,
#          ('息子', '着心地'): 4,
#          ('息子', 'みたい'): 8,
#          ('息子', 'スキー'): 15,
#          ('息子', '楽しみ'): 6,
#          ('サイズ', 'cm'): 4,
#          ('サイズ', '上'): 7,
#          ('サイズ', '紐'): 28,
#          ('サイズ', '調節'): 39,
#          ('サイズ', '大丈夫'): 14,
#          ('サイズ', '下'): 12,
#          ('サイズ', '細身'): 2,
#          ('サイズ', '息子'): 12,
#          ('サイズ', 'デザイン'): 35,
#          ('サイズ', '着心地'): 3,
#          ('サイズ', 'みたい'): 16,
#          ('サイズ', 'スキー'): 27,
#          ('サイズ', '楽しみ'): 12,
#          ('上', '紐'): 3,
#          ('上', '調節'): 4,
#          ('上', '大丈夫'): 1,
#          ('上', '下'): 8,
#          ('上', '細身'): 1,
#          ('上', '息子'): 4,
#          ('上', 'デザイン'): 3,
#          ('上', '着心地'): 1,
#          ('上', 'みたい'): 2,
#          ('上', 'スキー'): 2,
#          ('上', '楽しみ'): 4,
#          ('紐', '調節'): 6,
#          ('紐', '大丈夫'): 3,
#          ('紐', '下'): 2,
#          ('紐', '紐'): 8,
#          ('紐', '細身'): 2,
#          ('紐', '息子'): 4,
#          ('紐', 'デザイン'): 6,
#          ('紐', '着心地'): 2,
#          ('紐', 'みたい'): 2,
#          ('紐', 'スキー'): 3,
#          ('紐', '楽しみ'): 2,
#          ('調節', '大丈夫'): 9,
#          ('調節', '下'): 2,
#          ('調節', '紐'): 9,
#          ('調節', '調節'): 6,
#          ('調節', '細身'): 2,
#          ('調節', '息子'): 7,
#          ('調節', 'デザイン'): 10,
#          ('調節', '着心地'): 3,
#          ('調節', 'みたい'): 4,
#          ('調節', 'スキー'): 7,
#          ('調節', '楽しみ'): 6,
#          ('大丈夫', '下'): 1,
#          ('大丈夫', '紐'): 3,
#          ('大丈夫', '調節'): 6,
#          ('大丈夫', '細身'): 1,
#          ('大丈夫', '息子'): 4,
#          ('大丈夫', 'デザイン'): 6,
#          ('大丈夫', '着心地'): 2,
#          ('大丈夫', 'みたい'): 3,
#          ('大丈夫', 'スキー'): 6,
#          ('大丈夫', '楽しみ'): 3,
#          ('下', '紐'): 2,
#          ('下', '調節'): 2,
#          ('下', '細身'): 1,
#          ('下', '息子'): 6,
#          ('下', 'デザイン'): 1,
#          ('下', '着心地'): 1,
#          ('下', 'みたい'): 4,
#          ('下', 'スキー'): 4,
#          ('下', '楽しみ'): 4,
#          ('細身', '息子'): 7,
#          ('細身', 'デザイン'): 4,
#          ('細身', '着心地'): 1,
#          ('細身', 'みたい'): 1,
#          ('細身', 'スキー'): 3,
#          ('細身', '楽しみ'): 2,
#          ('デザイン', '着心地'): 1,
#          ('デザイン', 'みたい'): 1,
#          ('デザイン', '息子'): 11,
#          ('デザイン', 'スキー'): 5,
#          ('デザイン', '楽しみ'): 5,
#          ('着心地', 'みたい'): 1,
#          ('着心地', '息子'): 1,
#          ('着心地', 'スキー'): 1,
#          ('着心地', '楽しみ'): 1,
#          ('みたい', '息子'): 2,
#          ('みたい', 'スキー'): 5,
#          ('みたい', '楽しみ'): 2,
#          ('スキー', '楽しみ'): 6,
#          ('普段', 'センチ'): 6,
#          ('普段', '洋服'): 4,
#          ('普段', '小学校'): 1,
#          ('普段', '年生'): 1,
#          ('普段', '息子'): 6,
#          ('普段', '購入'): 18,
#          ('普段', 'さ'): 8,
#          ('普段', '調整'): 12,
#          ('普段', '問題'): 6,
#          ('普段', 'そう'): 17,
#          ('普段', '年'): 4,
#          ('普段', '子供'): 6,
#          ('普段', 'ウェア'): 5,
#          ('普段', '迷子'): 1,
#          ('普段', '防止'): 1,
#          ('普段', '為'): 1,
#          ('普段', '派手'): 1,
#          ('普段', '色'): 2,
#          ('普段', 'もの'): 2,
#          ('普段', 'の'): 6,
#          ('普段', '値段'): 3,
#          ('普段', 'デザイン'): 7,
#          ('普段', '満足'): 3,
#          ('普段', '他'): 1,
#          ('普段', 'サイト'): 1,
#          ('普段', 'くま'): 1,
#          ('普段', '断トツ'): 1,
#          ('普段', 'パンツ'): 2,
#          ('普段', '裏'): 1,
#          ('普段', '素材'): 1,
#          ('普段', '見た目'): 2,
#          ('普段', 'クオリティ'): 2,
#          ('普段', '商品'): 3,
#          ('普段', 'びっくり'): 1,
#          ('普段', '想像'): 2,
#          ('普段', '以上'): 1,
#          ('普段', '私'): 1,
#          ('センチ', '洋服'): 2,
#          ('センチ', '小学校'): 7,
#          ('センチ', '年生'): 4,
#          ('センチ', '息子'): 19,
#          ('センチ', 'センチ'): 37,
#          ('センチ', '購入'): 75,
#          ('センチ', 'さ'): 20,
#          ('センチ', '調整'): 29,
#          ('センチ', '問題'): 21,
#          ('センチ', 'そう'): 46,
#          ('センチ', '年'): 13,
#          ('センチ', '子供'): 13,
#          ('センチ', 'ウェア'): 8,
#          ('センチ', '迷子'): 2,
#          ('センチ', '防止'): 2,
#          ('センチ', '為'): 3,
#          ('センチ', '派手'): 3,
#          ('センチ', '色'): 13,
#          ('センチ', 'もの'): 11,
#          ('センチ', 'の'): 42,
#          ('センチ', '値段'): 17,
#          ('センチ', 'デザイン'): 25,
#          ('センチ', '満足'): 10,
#          ('センチ', '他'): 3,
#          ('センチ', 'サイト'): 4,
#          ('センチ', 'くま'): 2,
#          ('センチ', '断トツ'): 2,
#          ('センチ', 'パンツ'): 10,
#          ('センチ', '裏'): 2,
#          ('センチ', '素材'): 4,
#          ('センチ', '見た目'): 2,
#          ('センチ', 'クオリティ'): 2,
#          ('センチ', '商品'): 4,
#          ('センチ', 'びっくり'): 2,
#          ('センチ', '想像'): 2,
#          ('センチ', '以上'): 7,
#          ('センチ', '私'): 2,
#          ('洋服', '小学校'): 1,
#          ('洋服', '年生'): 1,
#          ('洋服', '息子'): 1,
#          ('洋服', 'センチ'): 3,
#          ('洋服', '購入'): 3,
#          ('洋服', 'さ'): 2,
#          ('洋服', '調整'): 5,
#          ('洋服', '問題'): 2,
#          ('洋服', 'そう'): 4,
#          ('洋服', '年'): 2,
#          ('洋服', '子供'): 1,
#          ('洋服', 'ウェア'): 2,
#          ('洋服', '迷子'): 1,
#          ('洋服', '防止'): 1,
#          ('洋服', '為'): 1,
#          ('洋服', '派手'): 1,
#          ('洋服', '色'): 1,
#          ('洋服', 'もの'): 1,
#          ('洋服', 'の'): 2,
#          ('洋服', '値段'): 1,
#          ('洋服', 'デザイン'): 2,
#          ('洋服', '満足'): 1,
#          ('洋服', '他'): 1,
#          ('洋服', 'サイト'): 1,
#          ('洋服', 'くま'): 1,
#          ('洋服', '断トツ'): 1,
#          ('洋服', 'パンツ'): 1,
#          ('洋服', '裏'): 1,
#          ('洋服', '素材'): 1,
#          ('洋服', '見た目'): 1,
#          ('洋服', 'クオリティ'): 1,
#          ('洋服', '商品'): 1,
#          ('洋服', 'びっくり'): 1,
#          ('洋服', '想像'): 1,
#          ('洋服', '以上'): 1,
#          ('洋服', '私'): 1,
#          ('小学校', '年生'): 2,
#          ('小学校', '息子'): 1,
#          ('小学校', 'センチ'): 4,
#          ('小学校', '購入'): 7,
#          ('小学校', 'さ'): 2,
#          ('小学校', '調整'): 2,
#          ('小学校', '問題'): 2,
#          ('小学校', 'そう'): 3,
#          ('小学校', '年'): 3,
#          ('小学校', '子供'): 1,
#          ('小学校', 'ウェア'): 3,
#          ('小学校', '迷子'): 1,
#          ('小学校', '防止'): 1,
#          ('小学校', '為'): 2,
#          ('小学校', '派手'): 1,
#          ('小学校', '色'): 1,
#          ('小学校', 'もの'): 1,
#          ('小学校', 'の'): 10,
#          ('小学校', '値段'): 2,
#          ('小学校', 'デザイン'): 2,
#          ('小学校', '満足'): 1,
#          ('小学校', '他'): 1,
#          ('小学校', 'サイト'): 1,
#          ('小学校', 'くま'): 1,
#          ('小学校', '断トツ'): 1,
#          ('小学校', 'パンツ'): 1,
#          ('小学校', '裏'): 1,
#          ('小学校', '素材'): 1,
#          ('小学校', '見た目'): 1,
#          ('小学校', 'クオリティ'): 1,
#          ('小学校', '商品'): 1,
#          ('小学校', 'びっくり'): 1,
#          ('小学校', '想像'): 1,
#          ('小学校', '以上'): 1,
#          ('小学校', '私'): 1,
#          ('年生', '息子'): 3,
#          ('年生', 'センチ'): 7,
#          ('年生', '購入'): 18,
#          ('年生', 'さ'): 5,
#          ('年生', '調整'): 7,
#          ('年生', '問題'): 5,
#          ('年生', 'そう'): 12,
#          ('年生', '年'): 5,
#          ('年生', '子供'): 7,
#          ('年生', 'ウェア'): 8,
#          ('年生', '迷子'): 1,
#          ('年生', '防止'): 1,
#          ('年生', '為'): 5,
#          ('年生', '派手'): 1,
#          ('年生', '色'): 8,
#          ('年生', 'もの'): 3,
#          ('年生', 'の'): 7,
#          ('年生', '値段'): 5,
#          ('年生', 'デザイン'): 10,
#          ('年生', '満足'): 5,
#          ('年生', '他'): 1,
#          ('年生', 'サイト'): 1,
#          ('年生', 'くま'): 1,
#          ('年生', '断トツ'): 1,
#          ('年生', 'パンツ'): 2,
#          ('年生', '裏'): 1,
#          ('年生', '素材'): 1,
#          ('年生', '見た目'): 1,
#          ('年生', 'クオリティ'): 1,
#          ('年生', '商品'): 4,
#          ('年生', 'びっくり'): 1,
#          ('年生', '想像'): 1,
#          ('年生', '以上'): 1,
#          ('年生', '私'): 1,
#          ('息子', 'センチ'): 14,
#          ('息子', '購入'): 67,
#          ('息子', 'さ'): 18,
#          ('息子', '調整'): 18,
#          ('息子', '問題'): 15,
#          ('息子', 'そう'): 34,
#          ('息子', '年'): 8,
#          ('息子', '子供'): 12,
#          ('息子', 'ウェア'): 15,
#          ('息子', '迷子'): 1,
#          ('息子', '防止'): 1,
#          ('息子', '為'): 4,
#          ('息子', '派手'): 2,
#          ('息子', '色'): 6,
#          ('息子', 'もの'): 2,
#          ('息子', 'の'): 30,
#          ('息子', '値段'): 9,
#          ('息子', '満足'): 17,
#          ('息子', '他'): 2,
#          ('息子', 'サイト'): 2,
#          ('息子', 'くま'): 1,
#          ('息子', '断トツ'): 1,
#          ('息子', 'パンツ'): 8,
#          ('息子', '裏'): 1,
#          ('息子', '素材'): 2,
#          ('息子', '見た目'): 1,
#          ('息子', 'クオリティ'): 2,
#          ('息子', '商品'): 10,
#          ('息子', 'びっくり'): 1,
#          ('息子', '想像'): 1,
#          ('息子', '以上'): 1,
#          ('息子', '私'): 2,
#          ('購入', 'さ'): 48,
#          ('購入', '調整'): 66,
#          ('購入', '問題'): 28,
#          ('購入', 'そう'): 106,
#          ('購入', '年'): 32,
#          ('購入', '子供'): 29,
#          ('購入', 'ウェア'): 28,
#          ('購入', '迷子'): 1,
#          ('購入', '防止'): 1,
#          ('購入', '為'): 7,
#          ('購入', '派手'): 3,
#          ('購入', '色'): 25,
#          ('購入', 'もの'): 19,
#          ('購入', 'の'): 91,
#          ('購入', '値段'): 45,
#          ('購入', 'デザイン'): 56,
#          ('購入', '満足'): 55,
#          ('購入', '他'): 4,
#          ('購入', 'サイト'): 1,
#          ('購入', 'くま'): 1,
#          ('購入', '断トツ'): 1,
#          ('購入', 'パンツ'): 26,
#          ('購入', '裏'): 1,
#          ('購入', '素材'): 7,
#          ('購入', '見た目'): 3,
#          ('購入', 'クオリティ'): 2,
#          ('購入', '商品'): 35,
#          ('購入', 'びっくり'): 4,
#          ('購入', '想像'): 3,
#          ('購入', '以上'): 9,
#          ('購入', '私'): 4,
#          ('さ', '調整'): 21,
#          ('さ', '問題'): 5,
#          ('さ', 'さ'): 8,
#          ('さ', 'そう'): 39,
#          ('さ', '年'): 5,
#          ('さ', '子供'): 11,
#          ('さ', 'ウェア'): 9,
#          ('さ', '迷子'): 2,
#          ('さ', '防止'): 2,
#          ('さ', '為'): 2,
#          ('さ', '派手'): 2,
#          ('さ', '色'): 8,
#          ('さ', 'もの'): 7,
#          ('さ', 'の'): 28,
#          ('さ', '値段'): 8,
#          ('さ', 'デザイン'): 10,
#          ('さ', '満足'): 14,
#          ('さ', '他'): 3,
#          ('さ', 'サイト'): 2,
#          ('さ', 'くま'): 2,
#          ('さ', '断トツ'): 2,
#          ('さ', 'パンツ'): 8,
#          ('さ', '裏'): 2,
#          ('さ', '素材'): 4,
#          ('さ', '見た目'): 4,
#          ('さ', 'クオリティ'): 2,
#          ('さ', '商品'): 8,
#          ('さ', 'びっくり'): 2,
#          ('さ', '想像'): 2,
#          ('さ', '以上'): 5,
#          ('さ', '私'): 4,
#          ('調整', '問題'): 18,
#          ('調整', 'さ'): 11,
#          ('調整', 'そう'): 52,
#          ('調整', '年'): 8,
#          ('調整', '子供'): 12,
#          ('調整', 'ウェア'): 5,
#          ('調整', '迷子'): 1,
#          ('調整', '防止'): 1,
#          ('調整', '為'): 2,
#          ('調整', '派手'): 1,
#          ('調整', '色'): 12,
#          ('調整', 'もの'): 7,
#          ('調整', 'の'): 29,
#          ('調整', '値段'): 17,
#          ('調整', 'デザイン'): 20,
#          ('調整', '満足'): 15,
#          ('調整', '他'): 2,
#          ('調整', 'サイト'): 1,
#          ('調整', 'くま'): 1,
#          ('調整', '断トツ'): 1,
#          ('調整', 'パンツ'): 4,
#          ('調整', '裏'): 1,
#          ('調整', '素材'): 5,
#          ('調整', '見た目'): 4,
#          ('調整', 'クオリティ'): 1,
#          ('調整', '商品'): 9,
#          ('調整', 'びっくり'): 1,
#          ('調整', '想像'): 1,
#          ('調整', '以上'): 5,
#          ('調整', '私'): 3,
#          ('問題', 'さ'): 10,
#          ('問題', 'そう'): 20,
#          ('問題', '年'): 5,
#          ('問題', '子供'): 4,
#          ('問題', 'ウェア'): 2,
#          ('問題', '迷子'): 1,
#          ('問題', '防止'): 1,
#          ('問題', '為'): 1,
#          ('問題', '派手'): 1,
#          ('問題', '色'): 6,
#          ('問題', 'もの'): 1,
#          ('問題', 'の'): 12,
#          ('問題', '値段'): 7,
#          ('問題', 'デザイン'): 8,
#          ('問題', '満足'): 6,
#          ('問題', '他'): 1,
#          ('問題', 'サイト'): 1,
#          ('問題', 'くま'): 1,
#          ('問題', '断トツ'): 1,
#          ('問題', 'パンツ'): 4,
#          ('問題', '裏'): 1,
#          ('問題', '素材'): 2,
#          ('問題', '見た目'): 2,
#          ('問題', 'クオリティ'): 1,
#          ('問題', '商品'): 5,
#          ('問題', 'びっくり'): 1,
#          ('問題', '想像'): 1,
#          ('問題', '以上'): 2,
#          ('問題', '私'): 1,
#          ('そう', '年'): 3,
#          ('そう', 'そう'): 28,
#          ('そう', '子供'): 8,
#          ('そう', 'ウェア'): 10,
#          ('そう', '迷子'): 2,
#          ('そう', '防止'): 2,
#          ('そう', '為'): 2,
#          ('そう', '派手'): 2,
#          ('そう', '色'): 16,
#          ('そう', 'もの'): 13,
#          ('そう', 'の'): 36,
#          ('そう', '値段'): 14,
#          ('そう', 'デザイン'): 22,
#          ('そう', '満足'): 25,
#          ('そう', '他'): 2,
#          ('そう', 'サイト'): 2,
#          ('そう', 'くま'): 2,
#          ('そう', '断トツ'): 2,
#          ('そう', 'パンツ'): 9,
#          ('そう', '裏'): 2,
#          ('そう', '素材'): 3,
#          ('そう', '見た目'): 4,
#          ('そう', 'クオリティ'): 2,
#          ('そう', '商品'): 14,
#          ('そう', 'びっくり'): 2,
#          ('そう', '想像'): 3,
#          ('そう', '以上'): 2,
#          ('そう', '私'): 8,
#          ('年', 'そう'): 29,
#          ('年', '子供'): 8,
#          ('年', 'ウェア'): 6,
#          ('年', '迷子'): 1,
#          ('年', '防止'): 1,
#          ('年', '為'): 4,
#          ('年', '派手'): 2,
#          ('年', '色'): 3,
#          ('年', 'もの'): 2,
#          ('年', 'の'): 29,
#          ('年', '値段'): 12,
#          ('年', 'デザイン'): 10,
#          ('年', '満足'): 9,
#          ('年', '他'): 1,
#          ('年', 'サイト'): 1,
#          ('年', 'くま'): 1,
#          ('年', '断トツ'): 1,
#          ('年', 'パンツ'): 1,
#          ('年', '裏'): 1,
#          ('年', '素材'): 4,
#          ('年', '見た目'): 1,
#          ('年', 'クオリティ'): 1,
#          ('年', '商品'): 10,
#          ('年', 'びっくり'): 1,
#          ('年', '想像'): 1,
#          ('年', '以上'): 3,
#          ('年', '私'): 2,
#          ('子供', 'ウェア'): 14,
#          ('子供', '迷子'): 1,
#          ('子供', '防止'): 1,
#          ('子供', '為'): 3,
#          ('子供', '派手'): 1,
#          ('子供', '色'): 10,
#          ('子供', 'もの'): 6,
#          ('子供', 'の'): 30,
#          ('子供', '値段'): 17,
#          ('子供', 'デザイン'): 11,
#          ('子供', '満足'): 19,
#          ('子供', '他'): 3,
#          ('子供', 'サイト'): 1,
#          ('子供', 'くま'): 1,
#          ('子供', '断トツ'): 1,
#          ('子供', 'パンツ'): 6,
#          ('子供', '裏'): 1,
#          ('子供', '素材'): 1,
#          ('子供', '見た目'): 1,
#          ('子供', 'クオリティ'): 2,
#          ('子供', '商品'): 6,
#          ('子供', 'びっくり'): 2,
#          ('子供', '想像'): 1,
#          ('子供', '以上'): 1,
#          ('子供', '私'): 2,
#          ('ウェア', '迷子'): 1,
#          ('ウェア', '防止'): 1,
#          ('ウェア', '為'): 2,
#          ('ウェア', '派手'): 1,
#          ('ウェア', '色'): 7,
#          ('ウェア', 'もの'): 7,
#          ('ウェア', 'の'): 23,
#          ('ウェア', '値段'): 7,
#          ('ウェア', 'デザイン'): 13,
#          ('ウェア', '満足'): 9,
#          ('ウェア', '他'): 2,
#          ('ウェア', 'サイト'): 1,
#          ('ウェア', 'くま'): 1,
#          ('ウェア', '断トツ'): 1,
#          ('ウェア', 'パンツ'): 6,
#          ('ウェア', '裏'): 1,
#          ('ウェア', '素材'): 1,
#          ('ウェア', '見た目'): 1,
#          ('ウェア', 'クオリティ'): 1,
#          ('ウェア', '商品'): 6,
#          ('ウェア', 'びっくり'): 2,
#          ('ウェア', '想像'): 1,
#          ('ウェア', '以上'): 1,
#          ('ウェア', '私'): 3,
#          ('ウェア', 'ウェア'): 8,
#          ('迷子', '防止'): 1,
#          ('迷子', '為'): 1,
#          ('迷子', '派手'): 1,
#          ('迷子', '色'): 1,
#          ('迷子', 'もの'): 1,
#          ('迷子', 'の'): 1,
#          ('迷子', '値段'): 1,
#          ('迷子', 'デザイン'): 2,
#          ('迷子', '満足'): 1,
#          ('迷子', '他'): 1,
#          ('迷子', 'サイト'): 1,
#          ('迷子', 'くま'): 1,
#          ('迷子', '断トツ'): 1,
#          ('迷子', 'パンツ'): 1,
#          ('迷子', '裏'): 1,
#          ('迷子', '素材'): 1,
#          ('迷子', '見た目'): 1,
#          ('迷子', 'クオリティ'): 1,
#          ('迷子', '商品'): 1,
#          ('迷子', 'びっくり'): 1,
#          ('迷子', '想像'): 1,
#          ('迷子', '以上'): 1,
#          ('迷子', '私'): 1,
#          ('迷子', 'ウェア'): 1,
#          ('防止', '為'): 1,
#          ('防止', '派手'): 1,
#          ('防止', '色'): 1,
#          ('防止', 'もの'): 1,
#          ('防止', 'の'): 1,
#          ('防止', '値段'): 1,
#          ('防止', 'デザイン'): 2,
#          ('防止', '満足'): 1,
#          ('防止', '他'): 1,
#          ('防止', 'サイト'): 1,
#          ('防止', 'くま'): 1,
#          ('防止', '断トツ'): 1,
#          ('防止', 'パンツ'): 1,
#          ('防止', '裏'): 1,
#          ('防止', '素材'): 1,
#          ('防止', '見た目'): 1,
#          ('防止', 'クオリティ'): 1,
#          ('防止', '商品'): 1,
#          ('防止', 'びっくり'): 1,
#          ('防止', '想像'): 1,
#          ('防止', '以上'): 1,
#          ('防止', '私'): 1,
#          ('防止', 'ウェア'): 1,
#          ('為', '派手'): 1,
#          ('為', '色'): 1,
#          ('為', 'もの'): 2,
#          ('為', 'の'): 4,
#          ('為', '値段'): 4,
#          ('為', 'デザイン'): 3,
#          ('為', '満足'): 3,
#          ('為', '他'): 2,
#          ('為', 'サイト'): 1,
#          ('為', 'くま'): 1,
#          ('為', '断トツ'): 1,
#          ('為', 'パンツ'): 4,
#          ('為', '裏'): 1,
#          ('為', '素材'): 1,
#          ('為', '見た目'): 1,
#          ('為', 'クオリティ'): 1,
#          ('為', '商品'): 3,
#          ('為', 'びっくり'): 1,
#          ('為', '想像'): 1,
#          ('為', '以上'): 1,
#          ('為', '私'): 1,
#          ('為', 'ウェア'): 6,
#          ('派手', '色'): 2,
#          ('派手', 'もの'): 1,
#          ('派手', 'の'): 2,
#          ('派手', '値段'): 1,
#          ('派手', 'デザイン'): 2,
#          ('派手', '満足'): 2,
#          ('派手', '他'): 1,
#          ('派手', 'サイト'): 1,
#          ('派手', 'くま'): 1,
#          ('派手', '断トツ'): 1,
#          ('派手', 'パンツ'): 1,
#          ('派手', '裏'): 1,
#          ('派手', '素材'): 2,
#          ('派手', '見た目'): 1,
#          ('派手', 'クオリティ'): 1,
#          ('派手', '商品'): 1,
#          ('派手', 'びっくり'): 1,
#          ('派手', '想像'): 1,
#          ('派手', '以上'): 1,
#          ('派手', '私'): 1,
#          ('派手', 'ウェア'): 2,
#          ('色', 'もの'): 6,
#          ('色', 'の'): 6,
#          ('色', '値段'): 8,
#          ('色', 'デザイン'): 7,
#          ('色', '満足'): 12,
#          ('色', '他'): 2,
#          ('色', 'サイト'): 1,
#          ('色', 'くま'): 1,
#          ('色', '断トツ'): 1,
#          ('色', 'パンツ'): 3,
#          ('色', '裏'): 1,
#          ('色', '素材'): 1,
#          ('色', '見た目'): 1,
#          ('色', 'クオリティ'): 1,
#          ('色', '商品'): 4,
#          ('色', 'びっくり'): 1,
#          ('色', '想像'): 1,
#          ('色', '以上'): 1,
#          ('色', '私'): 4,
#          ('色', 'ウェア'): 2,
#          ('もの', 'の'): 11,
#          ('もの', '値段'): 4,
#          ('もの', 'デザイン'): 5,
#          ('もの', '満足'): 3,
#          ('もの', '他'): 1,
#          ('もの', 'サイト'): 1,
#          ('もの', 'くま'): 1,
#          ('もの', '断トツ'): 1,
#          ('もの', 'パンツ'): 5,
#          ('もの', '裏'): 1,
#          ('もの', '素材'): 2,
#          ('もの', '見た目'): 1,
#          ('もの', 'クオリティ'): 1,
#          ('もの', '商品'): 2,
#          ('もの', 'びっくり'): 2,
#          ('もの', '想像'): 1,
#          ('もの', '以上'): 5,
#          ('もの', '私'): 2,
#          ('もの', 'ウェア'): 2,
#          ('の', '値段'): 14,
#          ('の', 'デザイン'): 19,
#          ('の', '満足'): 27,
#          ('の', '他'): 1,
#          ('の', 'サイト'): 1,
#          ('の', 'くま'): 1,
#          ('の', '断トツ'): 1,
#          ('の', 'パンツ'): 10,
#          ('の', '裏'): 1,
#          ('の', '素材'): 3,
#          ('の', '見た目'): 2,
#          ('の', 'クオリティ'): 1,
#          ('の', '商品'): 20,
#          ('の', 'びっくり'): 2,
#          ('の', '想像'): 3,
#          ('の', '以上'): 1,
#          ('の', '私'): 5,
#          ('の', 'ウェア'): 9,
#          ('値段', 'デザイン'): 22,
#          ('値段', '満足'): 29,
#          ('値段', '他'): 1,
#          ('値段', 'サイト'): 1,
#          ('値段', 'くま'): 1,
#          ('値段', '断トツ'): 1,
#          ('値段', 'パンツ'): 5,
#          ('値段', '裏'): 1,
#          ('値段', '素材'): 1,
#          ('値段', '見た目'): 1,
#          ('値段', 'クオリティ'): 2,
#          ('値段', '商品'): 9,
#          ('値段', 'びっくり'): 2,
#          ('値段', '想像'): 1,
#          ('値段', '以上'): 9,
#          ('値段', '私'): 4,
#          ('値段', 'ウェア'): 7,
#          ('デザイン', '満足'): 31,
#          ('デザイン', '他'): 2,
#          ('デザイン', 'サイト'): 1,
#          ('デザイン', 'くま'): 1,
#          ('デザイン', 'デザイン'): 12,
#          ('デザイン', '断トツ'): 2,
#          ('デザイン', 'パンツ'): 8,
#          ('デザイン', '裏'): 2,
#          ('デザイン', '素材'): 6,
#          ('デザイン', '見た目'): 2,
#          ('デザイン', 'クオリティ'): 3,
#          ('デザイン', '商品'): 9,
#          ('デザイン', 'びっくり'): 2,
#          ('デザイン', '想像'): 2,
#          ('デザイン', '以上'): 2,
#          ('デザイン', '私'): 3,
#          ('デザイン', 'ウェア'): 4,
#          ('満足', '他'): 2,
#          ('満足', 'サイト'): 1,
#          ('満足', 'くま'): 1,
#          ('満足', 'デザイン'): 3,
#          ('満足', '断トツ'): 1,
#          ('満足', 'パンツ'): 6,
#          ('満足', '裏'): 1,
#          ('満足', '素材'): 2,
#          ('満足', '見た目'): 1,
#          ('満足', 'クオリティ'): 1,
#          ('満足', '商品'): 7,
#          ('満足', 'びっくり'): 1,
#          ('満足', '想像'): 1,
#          ('満足', '以上'): 1,
#          ('満足', '私'): 2,
#          ('満足', 'ウェア'): 2,
#          ('他', 'サイト'): 1,
#          ('他', 'くま'): 1,
#          ('他', 'デザイン'): 2,
#          ('他', '断トツ'): 1,
#          ('他', 'パンツ'): 4,
#          ('他', '裏'): 1,
#          ('他', '素材'): 1,
#          ('他', '見た目'): 1,
#          ('他', 'クオリティ'): 1,
#          ('他', '商品'): 1,
#          ('他', 'びっくり'): 1,
#          ('他', '想像'): 1,
#          ('他', '以上'): 1,
#          ('他', '私'): 1,
#          ('他', 'ウェア'): 1,
#          ('サイト', 'くま'): 1,
#          ('サイト', 'デザイン'): 1,
#          ('サイト', '断トツ'): 1,
#          ('サイト', 'パンツ'): 1,
#          ('サイト', '裏'): 1,
#          ('サイト', '素材'): 1,
#          ('サイト', '見た目'): 1,
#          ('サイト', 'クオリティ'): 1,
#          ('サイト', '商品'): 1,
#          ('サイト', 'びっくり'): 1,
#          ('サイト', '想像'): 1,
#          ('サイト', '以上'): 1,
#          ('サイト', '私'): 1,
#          ('サイト', 'ウェア'): 1,
#          ('くま', 'デザイン'): 1,
#          ('くま', '断トツ'): 1,
#          ('くま', 'パンツ'): 1,
#          ('くま', '裏'): 1,
#          ('くま', '素材'): 1,
#          ('くま', '見た目'): 1,
#          ('くま', 'クオリティ'): 1,
#          ('くま', '商品'): 1,
#          ('くま', 'びっくり'): 1,
#          ('くま', '想像'): 1,
#          ('くま', '以上'): 1,
#          ('くま', '私'): 1,
#          ('くま', 'ウェア'): 1,
#          ('断トツ', 'パンツ'): 1,
#          ('断トツ', '裏'): 1,
#          ('断トツ', '素材'): 1,
#          ('断トツ', '見た目'): 1,
#          ('断トツ', 'クオリティ'): 1,
#          ('断トツ', '商品'): 1,
#          ('断トツ', 'びっくり'): 1,
#          ('断トツ', '想像'): 1,
#          ('断トツ', '以上'): 1,
#          ('断トツ', '私'): 1,
#          ('断トツ', 'ウェア'): 1,
#          ('パンツ', '裏'): 1,
#          ('パンツ', '素材'): 1,
#          ('パンツ', '見た目'): 1,
#          ('パンツ', 'クオリティ'): 1,
#          ('パンツ', '商品'): 6,
#          ('パンツ', 'びっくり'): 1,
#          ('パンツ', '想像'): 1,
#          ('パンツ', '以上'): 4,
#          ('パンツ', '私'): 2,
#          ('パンツ', 'ウェア'): 1,
#          ('裏', '素材'): 1,
#          ('裏', '見た目'): 1,
#          ('裏', 'クオリティ'): 1,
#          ('裏', '商品'): 1,
#          ('裏', 'びっくり'): 1,
#          ('裏', '想像'): 1,
#          ('裏', '以上'): 1,
#          ('裏', '私'): 1,
#          ('裏', 'ウェア'): 1,
#          ('素材', '見た目'): 1,
#          ('素材', 'クオリティ'): 1,
#          ('素材', '商品'): 2,
#          ('素材', 'びっくり'): 2,
#          ('素材', '想像'): 1,
#          ('素材', '以上'): 1,
#          ('素材', '私'): 1,
#          ('素材', 'ウェア'): 1,
#          ('見た目', 'クオリティ'): 1,
#          ('見た目', '商品'): 1,
#          ('見た目', 'びっくり'): 1,
#          ('見た目', '想像'): 1,
#          ('見た目', '以上'): 1,
#          ('見た目', '私'): 1,
#          ('見た目', 'ウェア'): 1,
#          ('クオリティ', '商品'): 1,
#          ('クオリティ', 'びっくり'): 1,
#          ('クオリティ', '想像'): 1,
#          ('クオリティ', '以上'): 1,
#          ('クオリティ', '私'): 1,
#          ('クオリティ', 'ウェア'): 1,
#          ('商品', 'びっくり'): 1,
#          ('商品', '想像'): 1,
#          ('商品', '以上'): 2,
#          ('商品', '私'): 3,
#          ('商品', 'ウェア'): 2,
#          ('びっくり', '想像'): 1,
#          ('びっくり', '以上'): 1,
#          ('びっくり', '私'): 1,
#          ('びっくり', 'ウェア'): 1,
#          ('想像', '以上'): 2,
#          ('想像', '私'): 1,
#          ('想像', 'ウェア'): 1,
#          ('以上', '私'): 1,
#          ('以上', 'ウェア'): 1,
#          ('私', 'ウェア'): 5,
#          ('小学', '年'): 7,
#          ('小学', '息子'): 6,
#          ('小学', '柄'): 3,
#          ('小学', '派手'): 1,
#          ('小学', '好き'): 1,
#          ('小学', '色'): 7,
#          ('小学', '満足'): 2,
#          ('年', '息子'): 11,
#          ('年', '柄'): 4,
#          ('年', '好き'): 1,
#          ('息子', '柄'): 12,
#          ('息子', '好き'): 2,
#          ('柄', '派手'): 2,
#          ('柄', '息子'): 4,
#          ('柄', '好き'): 1,
#          ('柄', '色'): 1,
#          ('柄', '満足'): 13,
#          ('派手', '息子'): 3,
#          ('派手', '好き'): 2,
#          ('好き', '色'): 1,
#          ('好き', '満足'): 1,
#          ('小学', '年生'): 13,
#          ('小学', '子供'): 6,
#          ('小学', '用'): 7,
#          ('小学', '購入'): 12,
#          ('小学', 'ズボン'): 4,
#          ('小学', '調節'): 5,
#          ('小学', 'さ'): 3,
#          ('小学', 'そう'): 5,
#          ('年生', '用'): 7,
#          ('年生', 'ズボン'): 5,
#          ('年生', '調節'): 4,
#          ('子供', '用'): 28,
#          ('子供', '購入'): 46,
#          ('子供', 'ズボン'): 10,
#          ('子供', '調節'): 17,
#          ('子供', 'さ'): 14,
#          ('子供', 'そう'): 22,
#          ('用', '購入'): 69,
#          ('用', 'ズボン'): 4,
#          ('用', '調節'): 9,
#          ('用', 'さ'): 18,
#          ('用', 'そう'): 16,
#          ('購入', 'ズボン'): 28,
#          ('購入', '調節'): 51,
#          ('ズボン', '調節'): 10,
#          ('ズボン', 'さ'): 6,
#          ('ズボン', 'そう'): 10,
#          ('調節', 'さ'): 6,
#          ('調節', 'そう'): 37,
#          ('デザイン', 'さ'): 13,
#          ('デザイン', '&'): 3,
#          ('デザイン', 'amp'): 3,
#          ('デザイン', ';'): 1,
#          ('デザイン', '価格'): 2,
#          ('デザイン', '歳'): 3,
#          ('デザイン', 'ｃｍ'): 2,
#          ('デザイン', '購入'): 15,
#          ('デザイン', '丈'): 5,
#          ('デザイン', '大分'): 1,
#          ('デザイン', 'よう'): 6,
#          ('デザイン', 'そう'): 19,
#          ('さ', '&'): 5,
#          ('さ', 'amp'): 5,
#          ('さ', ';'): 1,
#          ('さ', '価格'): 3,
#          ('さ', '歳'): 1,
#          ('さ', 'ｃｍ'): 1,
#          ('さ', '購入'): 11,
#          ('さ', '丈'): 1,
#          ('さ', '大分'): 1,
#          ('さ', 'よう'): 9,
#          ('&', 'amp'): 11,
#          ('&', ';'): 1,
#          ('&', '価格'): 1,
#          ('&', '満足'): 3,
#          ('&', '歳'): 1,
#          ('&', 'ｃｍ'): 1,
#          ('&', '購入'): 3,
#          ('&', '丈'): 1,
#          ('&', '大分'): 1,
#          ('&', 'よう'): 1,
#          ('&', 'そう'): 3,
#          ('amp', ';'): 1,
#          ('amp', '価格'): 1,
#          ('amp', '満足'): 3,
#          ('amp', '歳'): 1,
#          ('amp', 'ｃｍ'): 1,
#          ('amp', '購入'): 4,
#          ('amp', '丈'): 1,
#          ('amp', '大分'): 1,
#          ('amp', 'よう'): 1,
#          ('amp', 'そう'): 3,
#          (';', '価格'): 1,
#          (';', '満足'): 1,
#          (';', '歳'): 1,
#          (';', 'ｃｍ'): 1,
#          (';', '購入'): 1,
#          (';', '丈'): 1,
#          (';', '大分'): 1,
#          (';', 'よう'): 1,
#          (';', 'そう'): 1,
#          ('価格', '満足'): 4,
#          ('価格', '歳'): 1,
#          ('価格', 'ｃｍ'): 1,
#          ('価格', '購入'): 5,
#          ('価格', '丈'): 1,
#          ('価格', '大分'): 1,
#          ('価格', 'よう'): 3,
#          ('価格', 'そう'): 2,
#          ('満足', '歳'): 2,
#          ('満足', 'ｃｍ'): 2,
#          ('満足', '購入'): 14,
#          ('満足', '丈'): 3,
#          ('満足', '大分'): 1,
#          ('満足', 'よう'): 5,
#          ('満足', 'そう'): 14,
#          ('歳', 'ｃｍ'): 2,
#          ('歳', '購入'): 24,
#          ('歳', '丈'): 1,
#          ('歳', '大分'): 1,
#          ('歳', 'よう'): 4,
#          ('歳', 'そう'): 11,
#          ('ｃｍ', '購入'): 14,
#          ('ｃｍ', '丈'): 1,
#          ('ｃｍ', '大分'): 1,
#          ('ｃｍ', 'よう'): 1,
#          ('ｃｍ', 'そう'): 12,
#          ('購入', '丈'): 16,
#          ('購入', '大分'): 1,
#          ('購入', 'よう'): 48,
#          ('丈', '大分'): 1,
#          ...})

# %%
tops = sorted(
    cnt_pairs.items(), 
    key=lambda x: x[1], reverse=True
    )[:50]

# %%
noun_1 = []
noun_2 = []
frequency = []

# データフレームの作成
for n,f in tops:
    noun_1.append(n[0])    
    noun_2.append(n[1])
    frequency.append(f)

df = pd.DataFrame({'前出名詞': noun_1, '後出名詞': noun_2, '出現頻度': frequency})

# 重み付きデータの設定
weighted_edges = np.array(df)

# %%
# グラフオブジェクトの生成
G = nx.Graph()

# 重み付きデータの読み込み
G.add_weighted_edges_from(weighted_edges)

# ネットワーク図の描画
plt.figure(figsize=(10,10))
nx.draw_networkx(G,
                 node_color = "c", 
                 node_size = 1000,
                 edge_color = "gray", 
                 font_family = "IPAexGothic") # フォント指定

plt.show()

# %% [markdown]
# ### 5.2. 関数化

# %%
def make_network(list_data, part_of_speech, size):
    
    output = []
    
    for sentence in list_data:
        t = Tokenizer()
        text = sentence
        result = t.tokenize(text)
        
        words = []
    
        for token in result:
            pos = token.part_of_speech.split(',')[0]
            if pos in part_of_speech:
                words.append(token.base_form)

        output.append(words)

    # 文単位の名詞ペアリストを生成
    pair_list = [
                 list(itertools.combinations(n, 2))
                 for n in output if len(output) >=2
                 ]

    # 名詞ペアリストの平坦化
    all_pairs = []
    for u in pair_list:
        all_pairs.extend(u)

    # 名詞ペアの頻度をカウント
    cnt_pairs = Counter(all_pairs)
    
    tops = sorted(
    cnt_pairs.items(), 
    key=lambda x: x[1], reverse=True
    )[:size]
    
    noun_1 = []
    noun_2 = []
    frequency = []

    # データフレームの作成
    for n,f in tops:
        noun_1.append(n[0])    
        noun_2.append(n[1])
        frequency.append(f)

    df = pd.DataFrame({'前出名詞': noun_1, '後出名詞': noun_2, '出現頻度': frequency})

    # 重み付きデータの設定
    weighted_edges = np.array(df)
    
    # グラフオブジェクトの生成
    G = nx.Graph()

    # 重み付きデータの読み込み
    G.add_weighted_edges_from(weighted_edges)

    # ネットワーク図の描画
    plt.figure(figsize=(10,10))
    nx.draw_networkx(G,
                     node_color = "c", 
                     node_size = 1000,
                     edge_color = "gray", 
                     font_family = "IPAexGothic") # フォント指定

    plt.show()

# %% [markdown]
# いくつか単語を除いてみて、実装してみる。word cloudでいうstop wordです。テキストマイニングは、このようにデータをどこまで前処理するかが肝みたいです。

# %%
# 「購入」を抜く
df_high[0] = df_high[0].str.replace('購入', '')
df_high.head()
# Out:
#                                                       0
# 1758  身長cmの息子にサイズcmを買いました。上は紐で調節して大丈夫ですが、下は紐を調節しても細身...
# 547   普段はセンチの洋服を着ている小学校年生の息子にセンチをしました。大きさはかなり大きかったです...
# 448   小学年の息子に買いました。柄はありますが、派手でもなく息子が好きな落ち着いた色でしたのでとて...
# 1458                 小学年生の子供用に。ズボンも絞って調節がきくしなかなかよさそうです。
# 1675  デザインの可愛さ&amp;価格に大満足です。歳ｃｍでをしましたが、丈を詰めても大分大きいよう...

# %%
# 複数の文字列を一気に抜きたいときはこう。正規表現
df_high[0] = df_high[0].str.replace('センチ|キロ', '', regex=True)
df_high.head()
# Out:
#                                                       0
# 1758  身長cmの息子にサイズcmを買いました。上は紐で調節して大丈夫ですが、下は紐を調節しても細身...
# 547   普段はの洋服を着ている小学校年生の息子にをしました。大きさはかなり大きかったですが、調整が出...
# 448   小学年の息子に買いました。柄はありますが、派手でもなく息子が好きな落ち着いた色でしたのでとて...
# 1458                 小学年生の子供用に。ズボンも絞って調節がきくしなかなかよさそうです。
# 1675  デザインの可愛さ&amp;価格に大満足です。歳ｃｍでをしましたが、丈を詰めても大分大きいよう...

# %%
# テスト
list_high = df_high[0].values.tolist()
make_network(list_high, "名詞")

# %% [markdown]
# ## 6. おわりに<a class="anchor" id="final-bullet"></a>
